# %% [markdown]
# # Setting up

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import datasets, tree
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.random import set_seed

# Import data
from preprocessing import load_diabetes_prepr

# Interpretability measures
from interpretability import PDP

import shap

# %%
def find_best_model(model, parameters, X_train, y_train): 
    clf = GridSearchCV(model, parameters, scoring=('neg_root_mean_squared_error'), cv=KFold())
    clf.fit(X_train, y_train)

    return clf

def print_errors(model, model_name, X_test, y_test):
    y_pred = model.predict(X_test)
    
    if model_name == "Neural network":
        y_pred = np.reshape(y_pred, len(y_test))
    
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    print("RMSE ({}): {}".format(model_name, rmse))
    r2 = r2_score(y_test, y_pred)
    print("R-squared score ({}) : {}".format(model_name, r2))

# %%
X, y, feature_names = load_diabetes_prepr()
seed = 3012

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

# %%
models = dict()
explainers = dict()
shap_values = dict()

# %% [markdown]
# # Decision tree regressor

# %% [markdown]
# ## Training model

# %%
model_name = "decision tree regressor"
parameters = {'criterion': ('squared_error', 'friedman_mse', 'absolute_error', 'poisson'), 'splitter': ('best', 'random') , 'min_samples_split': np.arange(2, 301)}
tr = tree.DecisionTreeRegressor(random_state=seed)

clf = find_best_model(tr, parameters, X_train, y_train)
print_errors(clf, model_name, X_test, y_test)

model = clf.best_estimator_
models[model_name] = model
model
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-fac8c7ac662b> in <module>
#       3 tr = tree.DecisionTreeRegressor(random_state=seed)
#       4
# ----> 5 clf = find_best_model(tr, parameters, X_train, y_train)
#       6 print_errors(clf, model_name, X_test, y_test)
#       7
#
# <ipython-input-2-38c4dc0cf6ed> in find_best_model(model, parameters, X_train, y_train)
#       1 def find_best_model(model, parameters, X_train, y_train):
#       2     clf = GridSearchCV(model, parameters, scoring=('neg_root_mean_squared_error'), cv=KFold())
# ----> 3     clf.fit(X_train, y_train)
#       4
#       5     return clf
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     849                     )
#     850                     for (cand_idx, parameters), (split_idx, (train, test)) in product(
# --> 851                         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852                     )
#     853                 )
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     209     def __call__(self, *args, **kwargs):
#     210         with config_context(**self.config):
# --> 211             return self.function(*args, **kwargs)
#     212
#     213
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     667             cloned_parameters[k] = clone(v, safe=False)
#     668
# --> 669         estimator = estimator.set_params(**cloned_parameters)
#     670
#     671     start_time = time.time()
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/sklearn/base.py in set_params(self, **params)
#     232             # Simple optimization to gain speed (inspect is slow)
#     233             return self
# --> 234         valid_params = self.get_params(deep=True)
#     235
#     236         nested_params = defaultdict(dict)  # grouped by prefix
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/sklearn/base.py in get_params(self, deep)
#     202         """
#     203         out = dict()
# --> 204         for key in self._get_param_names():
#     205             value = getattr(self, key)
#     206             if deep and hasattr(value, "get_params"):
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/sklearn/base.py in _get_param_names(cls)
#     167         # introspect the constructor arguments to find the model parameters
#     168         # to represent
# --> 169         init_signature = inspect.signature(init)
#     170         # Consider the constructor parameters excluding 'self'
#     171         parameters = [
#
# /usr/local/lib/python3.7/inspect.py in signature(obj, follow_wrapped)
#    3081 def signature(obj, *, follow_wrapped=True):
#    3082     """Get a signature object for the passed callable."""
# -> 3083     return Signature.from_callable(obj, follow_wrapped=follow_wrapped)
#    3084
#    3085
#
# /usr/local/lib/python3.7/inspect.py in from_callable(cls, obj, follow_wrapped)
#    2831         """Constructs Signature for the given callable object."""
#    2832         return _signature_from_callable(obj, sigcls=cls,
# -> 2833                                         follow_wrapper_chains=follow_wrapped)
#    2834
#    2835     @property
#
# /usr/local/lib/python3.7/inspect.py in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, sigcls)
#    2282         # If it's a pure Python function, or an object that is duck type
#    2283         # of a Python function (Cython functions, for instance), then:
# -> 2284         return _signature_from_function(sigcls, obj)
#    2285
#    2286     if _signature_is_builtin(obj):
#
# /usr/local/lib/python3.7/inspect.py in _signature_from_function(cls, func)
#    2119
#    2120     is_duck_function = False
# -> 2121     if not isfunction(func):
#    2122         if _signature_is_functionlike(func):
#    2123             is_duck_function = True
#
# /usr/local/lib/python3.7/inspect.py in isfunction(object)
#     167         __annotations__ dict of parameter annotations
#     168         __kwdefaults__  dict of keyword only parameters with defaults"""
# --> 169     return isinstance(object, types.FunctionType)
#     170
#     171 def isgeneratorfunction(object):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Intrinsic interpretability

# %%
df = pd.Series(data=model.feature_importances_, index=feature_names)
df.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Partial dependence plot

# %%
categorical = [False for _ in range(11)]
categorical[1] = True

for i in range(X_test.shape[1]):
    PDP(i, feature_names[i], model, X_test, y_test, categorical=categorical[i])
    plt.show()
    plt.close()

### This is suddenly broken.. NO IDEA WHY, no changes made here..

# %% [markdown]
# ### SHAP

# %%
### Make seperate plot for each one, and also one with all the shaps combined (can be used later in the report)
idx = 4
model_name = "decision tree regressor"

X_test_df = pd.DataFrame(X_test, columns=feature_names)

explainers[model_name] = shap.KernelExplainer(model.predict, X_train)
shap_test = explainers[model_name].shap_values(X_test_df.iloc[idx])

# PLOT SHAPLEY VALUES IN NORMAL WAY

shap.initjs()
shap.force_plot(explainers[model_name].expected_value, shap_test, X_test_df.iloc[idx])
# shap.force_plot(explainer.expected_value[1], shap_test[1], X_test_df.iloc[idx]) # for decision trees
# Out:
# Using 353 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='i4I5FR7EKPSO1VUV8VM2D'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 147.6373937677054, "outValue": 125.00000000000026, "link": "identity", "featureNames": ["age", "sex", "bmi", "bp", "s1", "s2", "s3", "s4", "s5", "s6"], "features": {"1": {"effect": -1.2419494392479677, "value": 1.0654884797514645}, "2": {"effect": -27.630330666246955, "value": -0.5383473358194506}, "3": {"effect": -11.709387823483375, "value": 0.24269329657561015}, "6": {"effect": -2.5407487474810004, "value": 0.6355895188230916}, "8": {"effect": 21.96195532478013, "value": 0.8071718197783121}, "9": {"effect": -1.4769324160259636, "value": 0.41275676235612696}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i4I5FR7EKPSO1VUV8VM2D')
#   );
# </script>

# %% [markdown]
# ### Global Shap

# %%
shap_values_all = dict()
X_test_df = pd.DataFrame(X_test, columns=feature_names)

explainer = explainers[model_name]
shap_values[model_name] = explainer.shap_values(X_test_df.iloc[:5])
shap_values_all = shap_values[model_name]
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
shapley_feat_imps = pd.DataFrame(index=feature_names)

shap_value = shap_values_all
feat_imps = np.mean(np.abs(shap_value), axis=0)
feat_imps /= np.sum(feat_imps)
shapley_feat_imps.insert(0, model_name, feat_imps)
shapley_feat_imps.plot.bar()
plt.show()

# %% [markdown]
# # Linear regression models

# %% [markdown]
# ## Training model

# %%
model_name = "linear regression"
parameters = {}
linreg = LinearRegression()

clf = find_best_model(linreg, parameters, X_train, y_train)
print_errors(clf, model_name, X_test, y_test)

model = clf.best_estimator_
models[model_name] = model
model
# Out:
# RMSE (linear regression): 58.94293390689424
# R-squared score (linear regression) : 0.543872754881746
# LinearRegression()

# %% [markdown]
# Also tried Lasso and Ridge regression, but their errors were consistently larger

# %% [markdown]
# ## Intrinsic interpretability

# %%
df = pd.Series(data=np.abs(model.coef_)/np.sum(np.abs(model.coef_)), index=feature_names)
df.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Partial dependence plot

# %%
categorical = [False for _ in range(11)]
categorical[1] = True

for i in range(X_test.shape[1]):
    PDP(i, feature_names[i], model, X_test, y_test, categorical=categorical[i])
    plt.show()
    plt.close()

# %% [markdown]
# ### SHAP

# %%
### Make seperate plot for each one, and also one with all the shaps combined (can be used later in the report)
idx = 4
model_name = "linear regression"

X_test_df = pd.DataFrame(X_test, columns=feature_names)

explainers[model_name] = shap.KernelExplainer(model.predict, X_train)

shap_test = explainers[model_name].shap_values(X_test_df.iloc[idx])

# PLOT SHAPLEY VALUES IN NORMAL WAY

shap.initjs()
shap.force_plot(explainers[model_name].expected_value, shap_test, X_test_df.iloc[idx])
# shap.force_plot(explainer.expected_value[1], shap_test[1], X_test_df.iloc[idx]) # for decision trees
# Out:
# Using 353 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iMKTZ1UCD0XL9FJMR87U9'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 147.6373937677054, "outValue": 129.1035899130169, "link": "identity", "featureNames": ["age", "sex", "bmi", "bp", "s1", "s2", "s3", "s4", "s5", "s6"], "features": {"0": {"effect": -1.8801431822712582, "value": 1.3350883235096633}, "1": {"effect": -12.309117405724106, "value": 1.0654884797514645}, "2": {"effect": -11.592965007655902, "value": -0.5383473358194506}, "3": {"effect": 3.557702036250408, "value": 0.24269329657561015}, "4": {"effect": -32.08316244667867, "value": 1.3555466169207542}, "5": {"effect": 10.815303691750799, "value": 1.0191648422021304}, "6": {"effect": -0.045759704191557456, "value": 0.6355895188230916}, "7": {"effect": -0.16286366978083353, "value": -0.054499187536269665}, "8": {"effect": 23.49855015406103, "value": 0.8071718197783121}, "9": {"effect": 1.6686516795515942, "value": 0.41275676235612696}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iMKTZ1UCD0XL9FJMR87U9')
#   );
# </script>

# %%
shap_values_all = dict()
X_test_df = pd.DataFrame(X_test, columns=feature_names)

explainer = explainers[model_name]
shap_values[model_name] = explainer.shap_values(X_test_df.iloc[:5])
shap_values_all = shap_values[model_name]
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
shapley_feat_imps = pd.DataFrame(index=feature_names)

shap_value = shap_values_all
feat_imps = np.mean(np.abs(shap_value), axis=0)
feat_imps /= np.sum(feat_imps)
shapley_feat_imps.insert(0, model_name, feat_imps)
shapley_feat_imps.plot.bar()
plt.show()

# %% [markdown]
# # KNN regressor

# %% [markdown]
# ## Training model

# %%
model_name = "k-nearest neighbors"
parameters = {'n_neighbors': np.arange(1, 280), 'weights': ('uniform', 'distance')}
kNN = KNeighborsRegressor()

clf = find_best_model(kNN, parameters, X_train, y_train)
print_errors(clf, model_name, X_test, y_test)

model = clf.best_estimator_
model
# Out:
# RMSE (k-nearest neighbors): 64.45688846172169
# R-squared score (k-nearest neighbors) : 0.4545421586812478
# KNeighborsRegressor(n_neighbors=18, weights='distance')

# %% [markdown]
# ## Partial dependence plot

# %%
categorical = [False for _ in range(11)]
categorical[1] = True

for i in range(X_test.shape[1]):
    PDP(i, feature_names[i], model, X_test, y_test, categorical=categorical[i])
    plt.show()
    plt.close()

# %% [markdown]
# ### SHAP

# %%
### Make seperate plot for each one, and also one with all the shaps combined (can be used later in the report)
idx = 4
model_name = "k-nearest neighbors"

X_test_df = pd.DataFrame(X_test, columns=feature_names)

explainers[model_name] = shap.KernelExplainer(model.predict, X_train)

shap_test = explainers[model_name].shap_values(X_test_df.iloc[idx])

# PLOT SHAPLEY VALUES IN NORMAL WAY

shap.initjs()
shap.force_plot(explainers[model_name].expected_value, shap_test, X_test_df.iloc[idx])
# shap.force_plot(explainer.expected_value[1], shap_test[1], X_test_df.iloc[idx]) # for decision trees
# Out:
# Using 353 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iIT4IOT7ARSNOMKPYS40G'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 147.63739376770542, "outValue": 167.1395267704139, "link": "identity", "featureNames": ["age", "sex", "bmi", "bp", "s1", "s2", "s3", "s4", "s5", "s6"], "features": {"0": {"effect": 8.972328641107143, "value": 1.3350883235096633}, "1": {"effect": -0.40191382983619367, "value": 1.0654884797514645}, "2": {"effect": -10.21352492678614, "value": -0.5383473358194506}, "3": {"effect": 3.547283255703291, "value": 0.24269329657561015}, "4": {"effect": 3.565088880348782, "value": 1.3555466169207542}, "5": {"effect": -0.7951431390870589, "value": 1.0191648422021304}, "6": {"effect": -3.2227948129914945, "value": 0.6355895188230916}, "7": {"effect": 0.43120141006841495, "value": -0.054499187536269665}, "8": {"effect": 14.990726739892162, "value": 0.8071718197783121}, "9": {"effect": 2.628880784289585, "value": 0.41275676235612696}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iIT4IOT7ARSNOMKPYS40G')
#   );
# </script>

# %%
shap_values_all = dict()
X_test_df = pd.DataFrame(X_test, columns=feature_names)

explainer = explainers[model_name]
shap_values[model_name] = explainer.shap_values(X_test_df.iloc[:5])
shap_values_all = shap_values[model_name]
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
shapley_feat_imps = pd.DataFrame(index=feature_names)

shap_value = shap_values_all
feat_imps = np.mean(np.abs(shap_value), axis=0)
feat_imps /= np.sum(feat_imps)
shapley_feat_imps.insert(0, model_name, feat_imps)
shapley_feat_imps.plot.bar()
plt.show()

# %% [markdown]
# # Neural network

# %%
X_, X_test, y_, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)
X_train, X_val, y_train, y_val = train_test_split(X_, y_, test_size=0.2, random_state=seed)

# %%
# Initialise neural network
BATCH_SIZE=64
INPUT_SIZE= X_train.shape[1]

set_seed(seed)

model = Sequential()
model.add(Input(INPUT_SIZE))
model.add(Dense(20, activation="relu"))
model.add(Dropout(0.1))
# model.add(Dense(10, activation="relu"))
# model.add(Dropout(0.1))
model.add(Dense(10, activation="relu"))
model.add(Dropout(0.1))
model.add(Dense(1))
model.compile(optimizer='adam',
                loss="mean_absolute_error",
                metrics=['mean_squared_error'])

n_epochs = 300
history = model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=n_epochs, validation_data=(X_val, y_val)) # validation_split=0.2)
# Out:
# Epoch 1/300
# 5/5 [==============================] - 1s 171ms/step - loss: 146.4270 - mean_squared_error: 27086.4674 - val_loss: 140.8831 - val_mean_squared_error: 25423.3105
# Epoch 2/300
# 5/5 [==============================] - 0s 11ms/step - loss: 147.9914 - mean_squared_error: 27120.5641 - val_loss: 140.7796 - val_mean_squared_error: 25395.7246
# Epoch 3/300
# 5/5 [==============================] - 0s 16ms/step - loss: 146.4534 - mean_squared_error: 26560.8151 - val_loss: 140.6728 - val_mean_squared_error: 25367.3555
# Epoch 4/300
# 5/5 [==============================] - 0s 12ms/step - loss: 152.5552 - mean_squared_error: 28749.9326 - val_loss: 140.5561 - val_mean_squared_error: 25335.6348
# Epoch 5/300
# 5/5 [==============================] - 0s 18ms/step - loss: 148.6716 - mean_squared_error: 27654.7334 - val_loss: 140.4284 - val_mean_squared_error: 25301.2031
# Epoch 6/300
# 5/5 [==============================] - 0s 17ms/step - loss: 146.2454 - mean_squared_error: 26251.7858 - val_loss: 140.2891 - val_mean_squared_error: 25263.5293
# Epoch 7/300
# 5/5 [==============================] - 0s 16ms/step - loss: 151.3184 - mean_squared_error: 28401.9531 - val_loss: 140.1385 - val_mean_squared_error: 25222.8086
# Epoch 8/300
# 5/5 [==============================] - 0s 14ms/step - loss: 143.1714 - mean_squared_error: 25689.3783 - val_loss: 139.9772 - val_mean_squared_error: 25179.2715
# Epoch 9/300
# 5/5 [==============================] - 0s 15ms/step - loss: 146.4945 - mean_squared_error: 26815.5312 - val_loss: 139.8003 - val_mean_squared_error: 25131.3418
# Epoch 10/300
# 5/5 [==============================] - 0s 11ms/step - loss: 146.8591 - mean_squared_error: 26861.5983 - val_loss: 139.6090 - val_mean_squared_error: 25079.3164
# Epoch 11/300
# 5/5 [==============================] - 0s 12ms/step - loss: 148.8412 - mean_squared_error: 27821.6784 - val_loss: 139.3988 - val_mean_squared_error: 25021.8242
# Epoch 12/300
# 5/5 [==============================] - 0s 17ms/step - loss: 148.7062 - mean_squared_error: 27533.5309 - val_loss: 139.1741 - val_mean_squared_error: 24960.2559
# Epoch 13/300
# 5/5 [==============================] - 0s 14ms/step - loss: 147.1751 - mean_squared_error: 27132.9033 - val_loss: 138.9322 - val_mean_squared_error: 24893.8613
# Epoch 14/300
# 5/5 [==============================] - 0s 12ms/step - loss: 145.5965 - mean_squared_error: 26167.0117 - val_loss: 138.6724 - val_mean_squared_error: 24822.8105
# Epoch 15/300
# 5/5 [==============================] - 0s 12ms/step - loss: 144.4839 - mean_squared_error: 25949.6455 - val_loss: 138.3933 - val_mean_squared_error: 24746.7598
# Epoch 16/300
# 5/5 [==============================] - 0s 16ms/step - loss: 142.6218 - mean_squared_error: 25260.7458 - val_loss: 138.0871 - val_mean_squared_error: 24664.1543
# Epoch 17/300
# 5/5 [==============================] - 0s 12ms/step - loss: 149.5464 - mean_squared_error: 27763.6494 - val_loss: 137.7579 - val_mean_squared_error: 24575.1152
# Epoch 18/300
# 5/5 [==============================] - 0s 12ms/step - loss: 148.0693 - mean_squared_error: 27246.1094 - val_loss: 137.4028 - val_mean_squared_error: 24479.9316
# Epoch 19/300
# 5/5 [==============================] - 0s 12ms/step - loss: 144.2417 - mean_squared_error: 26194.7832 - val_loss: 137.0189 - val_mean_squared_error: 24378.1426
# Epoch 20/300
# 5/5 [==============================] - 0s 12ms/step - loss: 144.3707 - mean_squared_error: 25845.9466 - val_loss: 136.6099 - val_mean_squared_error: 24269.8242
# Epoch 21/300
# 5/5 [==============================] - 0s 12ms/step - loss: 142.3805 - mean_squared_error: 25801.4082 - val_loss: 136.1695 - val_mean_squared_error: 24152.9336
# Epoch 22/300
# 5/5 [==============================] - 0s 12ms/step - loss: 143.6458 - mean_squared_error: 26074.4085 - val_loss: 135.6944 - val_mean_squared_error: 24026.7500
# Epoch 23/300
# 5/5 [==============================] - 0s 12ms/step - loss: 138.0059 - mean_squared_error: 24038.4912 - val_loss: 135.1864 - val_mean_squared_error: 23893.5098
# Epoch 24/300
# 5/5 [==============================] - 0s 11ms/step - loss: 140.6065 - mean_squared_error: 25283.3698 - val_loss: 134.6395 - val_mean_squared_error: 23750.3164
# Epoch 25/300
# 5/5 [==============================] - 0s 11ms/step - loss: 142.6432 - mean_squared_error: 25986.1953 - val_loss: 134.0493 - val_mean_squared_error: 23596.4551
# Epoch 26/300
# 5/5 [==============================] - 0s 14ms/step - loss: 140.6946 - mean_squared_error: 25022.4844 - val_loss: 133.4173 - val_mean_squared_error: 23433.9531
# Epoch 27/300
# 5/5 [==============================] - 0s 11ms/step - loss: 142.5925 - mean_squared_error: 25993.5400 - val_loss: 132.7479 - val_mean_squared_error: 23262.7598
# Epoch 28/300
# 5/5 [==============================] - 0s 11ms/step - loss: 142.1450 - mean_squared_error: 25273.6549 - val_loss: 132.0348 - val_mean_squared_error: 23082.5879
# Epoch 29/300
# 5/5 [==============================] - 0s 12ms/step - loss: 139.0965 - mean_squared_error: 24484.7826 - val_loss: 131.2674 - val_mean_squared_error: 22890.5703
# Epoch 30/300
# 5/5 [==============================] - 0s 23ms/step - loss: 146.5949 - mean_squared_error: 27305.3955 - val_loss: 130.4356 - val_mean_squared_error: 22682.6504
# Epoch 31/300
# 5/5 [==============================] - 0s 25ms/step - loss: 140.1571 - mean_squared_error: 25062.3210 - val_loss: 129.5397 - val_mean_squared_error: 22461.7949
# Epoch 32/300
# 5/5 [==============================] - 0s 18ms/step - loss: 136.0766 - mean_squared_error: 23712.3519 - val_loss: 128.5819 - val_mean_squared_error: 22226.8770
# Epoch 33/300
# 5/5 [==============================] - 0s 17ms/step - loss: 140.3777 - mean_squared_error: 24927.7917 - val_loss: 127.5670 - val_mean_squared_error: 21980.6621
# Epoch 34/300
# 5/5 [==============================] - 0s 15ms/step - loss: 136.0919 - mean_squared_error: 23960.4235 - val_loss: 126.4957 - val_mean_squared_error: 21724.0000
# Epoch 35/300
# 5/5 [==============================] - 0s 12ms/step - loss: 134.8140 - mean_squared_error: 23844.2272 - val_loss: 125.3584 - val_mean_squared_error: 21452.3750
# Epoch 36/300
# 5/5 [==============================] - 0s 13ms/step - loss: 132.9253 - mean_squared_error: 23119.6585 - val_loss: 124.1585 - val_mean_squared_error: 21168.5508
# Epoch 37/300
# 5/5 [==============================] - 0s 12ms/step - loss: 131.8033 - mean_squared_error: 22714.7826 - val_loss: 122.8869 - val_mean_squared_error: 20873.4316
# Epoch 38/300
# 5/5 [==============================] - 0s 12ms/step - loss: 128.4774 - mean_squared_error: 21986.1797 - val_loss: 121.6055 - val_mean_squared_error: 20567.1953
# Epoch 39/300
# 5/5 [==============================] - 0s 12ms/step - loss: 135.4722 - mean_squared_error: 24042.8923 - val_loss: 120.2927 - val_mean_squared_error: 20251.8652
# Epoch 40/300
# 5/5 [==============================] - 0s 12ms/step - loss: 128.8994 - mean_squared_error: 22154.1465 - val_loss: 118.9098 - val_mean_squared_error: 19929.8496
# Epoch 41/300
# 5/5 [==============================] - 0s 12ms/step - loss: 124.7860 - mean_squared_error: 21033.9922 - val_loss: 117.5154 - val_mean_squared_error: 19596.4688
# Epoch 42/300
# 5/5 [==============================] - 0s 15ms/step - loss: 128.3384 - mean_squared_error: 22116.1914 - val_loss: 116.0715 - val_mean_squared_error: 19250.3867
# Epoch 43/300
# 5/5 [==============================] - 0s 12ms/step - loss: 121.6634 - mean_squared_error: 20275.7354 - val_loss: 114.5787 - val_mean_squared_error: 18899.5039
# Epoch 44/300
# 5/5 [==============================] - 0s 12ms/step - loss: 126.2474 - mean_squared_error: 21821.8590 - val_loss: 113.0307 - val_mean_squared_error: 18538.3340
# Epoch 45/300
# 5/5 [==============================] - 0s 12ms/step - loss: 120.6941 - mean_squared_error: 20150.9639 - val_loss: 111.4880 - val_mean_squared_error: 18173.5488
# Epoch 46/300
# 5/5 [==============================] - 0s 15ms/step - loss: 121.5602 - mean_squared_error: 20761.0433 - val_loss: 109.8959 - val_mean_squared_error: 17801.6816
# Epoch 47/300
# 5/5 [==============================] - 0s 12ms/step - loss: 116.0403 - mean_squared_error: 19188.3727 - val_loss: 108.2639 - val_mean_squared_error: 17425.4531
# Epoch 48/300
# 5/5 [==============================] - 0s 12ms/step - loss: 112.8368 - mean_squared_error: 18185.2493 - val_loss: 106.5612 - val_mean_squared_error: 17042.7793
# Epoch 49/300
# 5/5 [==============================] - 0s 12ms/step - loss: 117.7558 - mean_squared_error: 19517.8092 - val_loss: 104.8027 - val_mean_squared_error: 16654.7188
# Epoch 50/300
# 5/5 [==============================] - 0s 12ms/step - loss: 110.4075 - mean_squared_error: 17977.5954 - val_loss: 103.0740 - val_mean_squared_error: 16272.4014
# Epoch 51/300
# 5/5 [==============================] - 0s 12ms/step - loss: 108.5335 - mean_squared_error: 17363.9251 - val_loss: 101.3807 - val_mean_squared_error: 15885.8838
# Epoch 52/300
# 5/5 [==============================] - 0s 12ms/step - loss: 113.7210 - mean_squared_error: 18267.7848 - val_loss: 99.8222 - val_mean_squared_error: 15492.6689
# Epoch 53/300
# 5/5 [==============================] - 0s 12ms/step - loss: 106.5592 - mean_squared_error: 16563.3914 - val_loss: 98.3827 - val_mean_squared_error: 15097.2012
# Epoch 54/300
# 5/5 [==============================] - 0s 13ms/step - loss: 103.1357 - mean_squared_error: 15911.9591 - val_loss: 96.9179 - val_mean_squared_error: 14704.4131
# Epoch 55/300
# 5/5 [==============================] - 0s 11ms/step - loss: 107.5920 - mean_squared_error: 16876.6898 - val_loss: 95.4087 - val_mean_squared_error: 14307.7793
# Epoch 56/300
# 5/5 [==============================] - 0s 12ms/step - loss: 103.2649 - mean_squared_error: 15962.8840 - val_loss: 93.9628 - val_mean_squared_error: 13911.1943
# Epoch 57/300
# 5/5 [==============================] - 0s 12ms/step - loss: 100.7658 - mean_squared_error: 15453.1312 - val_loss: 92.4980 - val_mean_squared_error: 13516.8281
# Epoch 58/300
# 5/5 [==============================] - 0s 12ms/step - loss: 98.1981 - mean_squared_error: 14496.4785 - val_loss: 91.0140 - val_mean_squared_error: 13129.5488
# Epoch 59/300
# 5/5 [==============================] - 0s 12ms/step - loss: 97.4792 - mean_squared_error: 14216.2993 - val_loss: 89.5330 - val_mean_squared_error: 12742.0840
# Epoch 60/300
# 5/5 [==============================] - 0s 15ms/step - loss: 89.2526 - mean_squared_error: 12399.1426 - val_loss: 88.0252 - val_mean_squared_error: 12361.6240
# Epoch 61/300
# 5/5 [==============================] - 0s 13ms/step - loss: 87.5242 - mean_squared_error: 11993.6257 - val_loss: 86.4121 - val_mean_squared_error: 11967.5820
# Epoch 62/300
# 5/5 [==============================] - 0s 19ms/step - loss: 91.3502 - mean_squared_error: 12651.2510 - val_loss: 84.7744 - val_mean_squared_error: 11573.1494
# Epoch 63/300
# 5/5 [==============================] - 0s 14ms/step - loss: 88.3390 - mean_squared_error: 12310.2827 - val_loss: 83.1951 - val_mean_squared_error: 11189.3037
# Epoch 64/300
# 5/5 [==============================] - 0s 14ms/step - loss: 85.9960 - mean_squared_error: 11575.5418 - val_loss: 81.5730 - val_mean_squared_error: 10806.8340
# Epoch 65/300
# 5/5 [==============================] - 0s 16ms/step - loss: 87.2560 - mean_squared_error: 11825.8047 - val_loss: 80.1652 - val_mean_squared_error: 10435.0508
# Epoch 66/300
# 5/5 [==============================] - 0s 12ms/step - loss: 81.2256 - mean_squared_error: 10521.7528 - val_loss: 78.8808 - val_mean_squared_error: 10078.2822
# Epoch 67/300
# 5/5 [==============================] - 0s 12ms/step - loss: 82.7869 - mean_squared_error: 10742.6934 - val_loss: 77.5615 - val_mean_squared_error: 9731.0332
# Epoch 68/300
# 5/5 [==============================] - 0s 15ms/step - loss: 78.6899 - mean_squared_error: 9854.3517 - val_loss: 76.2377 - val_mean_squared_error: 9402.4395
# Epoch 69/300
# 5/5 [==============================] - 0s 13ms/step - loss: 77.8143 - mean_squared_error: 9741.3221 - val_loss: 74.8434 - val_mean_squared_error: 9077.8262
# Epoch 70/300
# 5/5 [==============================] - 0s 13ms/step - loss: 78.6229 - mean_squared_error: 9850.8698 - val_loss: 73.4741 - val_mean_squared_error: 8778.1904
# Epoch 71/300
# 5/5 [==============================] - 0s 13ms/step - loss: 74.4086 - mean_squared_error: 8967.0827 - val_loss: 72.1439 - val_mean_squared_error: 8499.5400
# Epoch 72/300
# 5/5 [==============================] - 0s 13ms/step - loss: 73.4491 - mean_squared_error: 9060.9653 - val_loss: 70.7943 - val_mean_squared_error: 8232.9453
# Epoch 73/300
# 5/5 [==============================] - 0s 12ms/step - loss: 71.7928 - mean_squared_error: 8386.4821 - val_loss: 69.5038 - val_mean_squared_error: 7990.3628
# Epoch 74/300
# 5/5 [==============================] - 0s 12ms/step - loss: 68.3267 - mean_squared_error: 7491.6460 - val_loss: 68.2774 - val_mean_squared_error: 7770.8452
# Epoch 75/300
# 5/5 [==============================] - 0s 12ms/step - loss: 65.2057 - mean_squared_error: 7286.7508 - val_loss: 67.0618 - val_mean_squared_error: 7570.1489
# Epoch 76/300
# 5/5 [==============================] - 0s 15ms/step - loss: 65.9891 - mean_squared_error: 7220.9164 - val_loss: 65.9191 - val_mean_squared_error: 7388.7598
# Epoch 77/300
# 5/5 [==============================] - 0s 15ms/step - loss: 68.2026 - mean_squared_error: 7645.2172 - val_loss: 65.0059 - val_mean_squared_error: 7223.8477
# Epoch 78/300
# 5/5 [==============================] - 0s 12ms/step - loss: 66.9516 - mean_squared_error: 7549.0512 - val_loss: 64.2574 - val_mean_squared_error: 7077.4165
# Epoch 79/300
# 5/5 [==============================] - 0s 14ms/step - loss: 64.6152 - mean_squared_error: 6831.4167 - val_loss: 63.5448 - val_mean_squared_error: 6947.8374
# Epoch 80/300
# 5/5 [==============================] - 0s 17ms/step - loss: 60.6902 - mean_squared_error: 6349.9046 - val_loss: 62.8822 - val_mean_squared_error: 6836.4941
# Epoch 81/300
# 5/5 [==============================] - 0s 16ms/step - loss: 65.5131 - mean_squared_error: 7095.0688 - val_loss: 62.2235 - val_mean_squared_error: 6736.5469
# Epoch 82/300
# 5/5 [==============================] - 0s 15ms/step - loss: 64.0715 - mean_squared_error: 7023.3514 - val_loss: 61.5236 - val_mean_squared_error: 6646.1680
# Epoch 83/300
# 5/5 [==============================] - 0s 12ms/step - loss: 61.9474 - mean_squared_error: 6489.5788 - val_loss: 60.9354 - val_mean_squared_error: 6572.5298
# Epoch 84/300
# 5/5 [==============================] - 0s 14ms/step - loss: 61.5112 - mean_squared_error: 6365.5634 - val_loss: 60.4614 - val_mean_squared_error: 6512.6680
# Epoch 85/300
# 5/5 [==============================] - 0s 12ms/step - loss: 53.4011 - mean_squared_error: 4936.9573 - val_loss: 59.9785 - val_mean_squared_error: 6462.3325
# Epoch 86/300
# 5/5 [==============================] - 0s 14ms/step - loss: 55.1622 - mean_squared_error: 5239.5242 - val_loss: 59.5443 - val_mean_squared_error: 6416.1187
# Epoch 87/300
# 5/5 [==============================] - 0s 17ms/step - loss: 55.1941 - mean_squared_error: 5240.6858 - val_loss: 59.1005 - val_mean_squared_error: 6373.7002
# Epoch 88/300
# 5/5 [==============================] - 0s 14ms/step - loss: 57.7946 - mean_squared_error: 5742.2505 - val_loss: 58.6618 - val_mean_squared_error: 6339.4775
# Epoch 89/300
# 5/5 [==============================] - 0s 12ms/step - loss: 55.2554 - mean_squared_error: 5367.3630 - val_loss: 58.3489 - val_mean_squared_error: 6309.3320
# Epoch 90/300
# 5/5 [==============================] - 0s 12ms/step - loss: 54.4362 - mean_squared_error: 5237.0780 - val_loss: 58.1522 - val_mean_squared_error: 6275.9976
# Epoch 91/300
# 5/5 [==============================] - 0s 12ms/step - loss: 60.7587 - mean_squared_error: 6076.5458 - val_loss: 57.9701 - val_mean_squared_error: 6248.8213
# Epoch 92/300
# 5/5 [==============================] - 0s 15ms/step - loss: 58.2569 - mean_squared_error: 5791.3793 - val_loss: 57.7855 - val_mean_squared_error: 6219.9580
# Epoch 93/300
# 5/5 [==============================] - 0s 12ms/step - loss: 54.8911 - mean_squared_error: 5321.9814 - val_loss: 57.6243 - val_mean_squared_error: 6194.2212
# Epoch 94/300
# 5/5 [==============================] - 0s 13ms/step - loss: 56.3745 - mean_squared_error: 5407.2921 - val_loss: 57.4680 - val_mean_squared_error: 6168.6069
# Epoch 95/300
# 5/5 [==============================] - 0s 12ms/step - loss: 53.1730 - mean_squared_error: 4951.2078 - val_loss: 57.2838 - val_mean_squared_error: 6137.9644
# Epoch 96/300
# 5/5 [==============================] - 0s 18ms/step - loss: 56.2931 - mean_squared_error: 5313.1852 - val_loss: 57.1057 - val_mean_squared_error: 6109.4458
# Epoch 97/300
# 5/5 [==============================] - 0s 12ms/step - loss: 54.3480 - mean_squared_error: 5066.7957 - val_loss: 56.9128 - val_mean_squared_error: 6076.0962
# Epoch 98/300
# 5/5 [==============================] - 0s 12ms/step - loss: 55.2915 - mean_squared_error: 5224.8307 - val_loss: 56.7123 - val_mean_squared_error: 6041.6953
# Epoch 99/300
# 5/5 [==============================] - 0s 14ms/step - loss: 55.2109 - mean_squared_error: 5197.6708 - val_loss: 56.5340 - val_mean_squared_error: 6011.1152
# Epoch 100/300
# 5/5 [==============================] - 0s 13ms/step - loss: 53.9657 - mean_squared_error: 4845.2589 - val_loss: 56.3518 - val_mean_squared_error: 5979.6401
# Epoch 101/300
# 5/5 [==============================] - 0s 15ms/step - loss: 53.1952 - mean_squared_error: 4743.5208 - val_loss: 56.2123 - val_mean_squared_error: 5953.8003
# Epoch 102/300
# 5/5 [==============================] - 0s 12ms/step - loss: 53.9339 - mean_squared_error: 4997.5383 - val_loss: 56.0624 - val_mean_squared_error: 5922.8179
# Epoch 103/300
# 5/5 [==============================] - 0s 12ms/step - loss: 53.8654 - mean_squared_error: 4880.3319 - val_loss: 55.9276 - val_mean_squared_error: 5895.4795
# Epoch 104/300
# 5/5 [==============================] - 0s 12ms/step - loss: 55.2509 - mean_squared_error: 4970.0853 - val_loss: 55.8008 - val_mean_squared_error: 5866.0645
# Epoch 105/300
# 5/5 [==============================] - 0s 12ms/step - loss: 53.0674 - mean_squared_error: 4637.0030 - val_loss: 55.6850 - val_mean_squared_error: 5843.2915
# Epoch 106/300
# 5/5 [==============================] - 0s 12ms/step - loss: 52.2721 - mean_squared_error: 4961.8787 - val_loss: 55.5594 - val_mean_squared_error: 5814.0156
# Epoch 107/300
# 5/5 [==============================] - 0s 16ms/step - loss: 49.9803 - mean_squared_error: 4343.9701 - val_loss: 55.4045 - val_mean_squared_error: 5779.8530
# Epoch 108/300
# 5/5 [==============================] - 0s 12ms/step - loss: 54.7757 - mean_squared_error: 5399.8329 - val_loss: 55.2495 - val_mean_squared_error: 5742.4092
# Epoch 109/300
# 5/5 [==============================] - 0s 14ms/step - loss: 51.5276 - mean_squared_error: 4624.1826 - val_loss: 55.0829 - val_mean_squared_error: 5700.6680
# Epoch 110/300
# 5/5 [==============================] - 0s 13ms/step - loss: 53.2782 - mean_squared_error: 4924.6391 - val_loss: 54.9519 - val_mean_squared_error: 5668.7568
# Epoch 111/300
# 5/5 [==============================] - 0s 14ms/step - loss: 51.9415 - mean_squared_error: 4530.9637 - val_loss: 54.7963 - val_mean_squared_error: 5634.4800
# Epoch 112/300
# 5/5 [==============================] - 0s 12ms/step - loss: 50.8750 - mean_squared_error: 4394.4749 - val_loss: 54.6319 - val_mean_squared_error: 5602.0088
# Epoch 113/300
# 5/5 [==============================] - 0s 15ms/step - loss: 50.8177 - mean_squared_error: 4564.9769 - val_loss: 54.4588 - val_mean_squared_error: 5567.1182
# Epoch 114/300
# 5/5 [==============================] - 0s 17ms/step - loss: 49.9234 - mean_squared_error: 4216.1297 - val_loss: 54.2844 - val_mean_squared_error: 5533.9023
# Epoch 115/300
# 5/5 [==============================] - 0s 12ms/step - loss: 50.4603 - mean_squared_error: 4619.7986 - val_loss: 54.1003 - val_mean_squared_error: 5497.1450
# Epoch 116/300
# 5/5 [==============================] - 0s 19ms/step - loss: 51.7239 - mean_squared_error: 4585.4826 - val_loss: 53.9813 - val_mean_squared_error: 5463.7573
# Epoch 117/300
# 5/5 [==============================] - 0s 12ms/step - loss: 50.5834 - mean_squared_error: 4387.8824 - val_loss: 53.8542 - val_mean_squared_error: 5431.7798
# Epoch 118/300
# 5/5 [==============================] - 0s 15ms/step - loss: 50.6214 - mean_squared_error: 4351.5949 - val_loss: 53.7378 - val_mean_squared_error: 5407.4370
# Epoch 119/300
# 5/5 [==============================] - 0s 12ms/step - loss: 50.8514 - mean_squared_error: 4123.5838 - val_loss: 53.6499 - val_mean_squared_error: 5385.6753
# Epoch 120/300
# 5/5 [==============================] - 0s 12ms/step - loss: 52.9573 - mean_squared_error: 4946.7878 - val_loss: 53.5342 - val_mean_squared_error: 5359.6313
# Epoch 121/300
# 5/5 [==============================] - 0s 14ms/step - loss: 53.2325 - mean_squared_error: 4663.3128 - val_loss: 53.4221 - val_mean_squared_error: 5337.1816
# Epoch 122/300
# 5/5 [==============================] - 0s 17ms/step - loss: 51.7397 - mean_squared_error: 4223.7920 - val_loss: 53.3134 - val_mean_squared_error: 5313.3384
# Epoch 123/300
# 5/5 [==============================] - 0s 12ms/step - loss: 51.4775 - mean_squared_error: 4461.0864 - val_loss: 53.2193 - val_mean_squared_error: 5290.5503
# Epoch 124/300
# 5/5 [==============================] - 0s 11ms/step - loss: 51.1107 - mean_squared_error: 4705.3123 - val_loss: 53.1144 - val_mean_squared_error: 5264.4819
# Epoch 125/300
# 5/5 [==============================] - 0s 11ms/step - loss: 52.0475 - mean_squared_error: 4395.1290 - val_loss: 53.0072 - val_mean_squared_error: 5234.2515
# Epoch 126/300
# 5/5 [==============================] - 0s 17ms/step - loss: 49.9953 - mean_squared_error: 4066.5203 - val_loss: 52.8898 - val_mean_squared_error: 5201.0737
# Epoch 127/300
# 5/5 [==============================] - 0s 15ms/step - loss: 50.5704 - mean_squared_error: 4299.3597 - val_loss: 52.7889 - val_mean_squared_error: 5175.7847
# Epoch 128/300
# 5/5 [==============================] - 0s 11ms/step - loss: 55.6531 - mean_squared_error: 5213.7016 - val_loss: 52.6979 - val_mean_squared_error: 5154.4795
# Epoch 129/300
# 5/5 [==============================] - 0s 13ms/step - loss: 47.6117 - mean_squared_error: 3964.5147 - val_loss: 52.5805 - val_mean_squared_error: 5128.5684
# Epoch 130/300
# 5/5 [==============================] - 0s 12ms/step - loss: 49.8661 - mean_squared_error: 4319.3834 - val_loss: 52.4661 - val_mean_squared_error: 5105.4077
# Epoch 131/300
# 5/5 [==============================] - 0s 12ms/step - loss: 53.4412 - mean_squared_error: 4802.8861 - val_loss: 52.3687 - val_mean_squared_error: 5082.4268
# Epoch 132/300
# 5/5 [==============================] - 0s 13ms/step - loss: 51.3129 - mean_squared_error: 4505.4209 - val_loss: 52.2935 - val_mean_squared_error: 5064.4277
# Epoch 133/300
# 5/5 [==============================] - 0s 13ms/step - loss: 50.6986 - mean_squared_error: 4269.7484 - val_loss: 52.2093 - val_mean_squared_error: 5047.4424
# Epoch 134/300
# 5/5 [==============================] - 0s 13ms/step - loss: 51.2329 - mean_squared_error: 4383.9457 - val_loss: 52.1398 - val_mean_squared_error: 5027.7969
# Epoch 135/300
# 5/5 [==============================] - 0s 13ms/step - loss: 50.3704 - mean_squared_error: 4414.1110 - val_loss: 52.0412 - val_mean_squared_error: 5008.1367
# Epoch 136/300
# 5/5 [==============================] - 0s 12ms/step - loss: 50.7800 - mean_squared_error: 4426.5383 - val_loss: 51.9289 - val_mean_squared_error: 4986.1851
# Epoch 137/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.5187 - mean_squared_error: 3810.7374 - val_loss: 51.8338 - val_mean_squared_error: 4968.2676
# Epoch 138/300
# 5/5 [==============================] - 0s 13ms/step - loss: 51.5076 - mean_squared_error: 4587.9200 - val_loss: 51.7640 - val_mean_squared_error: 4953.7524
# Epoch 139/300
# 5/5 [==============================] - 0s 12ms/step - loss: 48.8076 - mean_squared_error: 3992.1444 - val_loss: 51.7036 - val_mean_squared_error: 4940.5522
# Epoch 140/300
# 5/5 [==============================] - 0s 12ms/step - loss: 49.3394 - mean_squared_error: 4179.3487 - val_loss: 51.6373 - val_mean_squared_error: 4918.3003
# Epoch 141/300
# 5/5 [==============================] - 0s 13ms/step - loss: 51.1962 - mean_squared_error: 4726.2472 - val_loss: 51.5951 - val_mean_squared_error: 4901.1226
# Epoch 142/300
# 5/5 [==============================] - 0s 13ms/step - loss: 49.0139 - mean_squared_error: 4225.8606 - val_loss: 51.5362 - val_mean_squared_error: 4882.2104
# Epoch 143/300
# 5/5 [==============================] - 0s 14ms/step - loss: 49.3449 - mean_squared_error: 4103.9218 - val_loss: 51.4676 - val_mean_squared_error: 4866.4570
# Epoch 144/300
# 5/5 [==============================] - 0s 12ms/step - loss: 49.1058 - mean_squared_error: 4063.6949 - val_loss: 51.3809 - val_mean_squared_error: 4849.2310
# Epoch 145/300
# 5/5 [==============================] - 0s 15ms/step - loss: 50.0361 - mean_squared_error: 4342.7944 - val_loss: 51.3045 - val_mean_squared_error: 4835.5645
# Epoch 146/300
# 5/5 [==============================] - 0s 12ms/step - loss: 50.3432 - mean_squared_error: 4206.2985 - val_loss: 51.2303 - val_mean_squared_error: 4828.0117
# Epoch 147/300
# 5/5 [==============================] - 0s 15ms/step - loss: 48.8718 - mean_squared_error: 4025.5015 - val_loss: 51.1618 - val_mean_squared_error: 4814.8804
# Epoch 148/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.7279 - mean_squared_error: 3809.7424 - val_loss: 51.0811 - val_mean_squared_error: 4797.7920
# Epoch 149/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.4931 - mean_squared_error: 3574.5374 - val_loss: 50.9979 - val_mean_squared_error: 4780.0815
# Epoch 150/300
# 5/5 [==============================] - 0s 12ms/step - loss: 48.5767 - mean_squared_error: 4166.6752 - val_loss: 50.9309 - val_mean_squared_error: 4766.3462
# Epoch 151/300
# 5/5 [==============================] - 0s 14ms/step - loss: 50.5220 - mean_squared_error: 4202.3280 - val_loss: 50.8647 - val_mean_squared_error: 4751.0806
# Epoch 152/300
# 5/5 [==============================] - 0s 14ms/step - loss: 49.7534 - mean_squared_error: 4244.7177 - val_loss: 50.8080 - val_mean_squared_error: 4737.2417
# Epoch 153/300
# 5/5 [==============================] - 0s 14ms/step - loss: 48.3799 - mean_squared_error: 3988.4594 - val_loss: 50.7428 - val_mean_squared_error: 4721.5840
# Epoch 154/300
# 5/5 [==============================] - 0s 12ms/step - loss: 49.6385 - mean_squared_error: 4012.7017 - val_loss: 50.6878 - val_mean_squared_error: 4705.0361
# Epoch 155/300
# 5/5 [==============================] - 0s 13ms/step - loss: 50.6609 - mean_squared_error: 4187.3145 - val_loss: 50.6256 - val_mean_squared_error: 4690.4644
# Epoch 156/300
# 5/5 [==============================] - 0s 14ms/step - loss: 50.6177 - mean_squared_error: 4249.1386 - val_loss: 50.5749 - val_mean_squared_error: 4681.3936
# Epoch 157/300
# 5/5 [==============================] - 0s 12ms/step - loss: 47.2415 - mean_squared_error: 3758.4994 - val_loss: 50.5181 - val_mean_squared_error: 4669.7837
# Epoch 158/300
# 5/5 [==============================] - 0s 12ms/step - loss: 48.6146 - mean_squared_error: 3976.8926 - val_loss: 50.4595 - val_mean_squared_error: 4658.7495
# Epoch 159/300
# 5/5 [==============================] - 0s 12ms/step - loss: 51.0637 - mean_squared_error: 4437.3039 - val_loss: 50.3929 - val_mean_squared_error: 4647.2725
# Epoch 160/300
# 5/5 [==============================] - 0s 13ms/step - loss: 47.3254 - mean_squared_error: 4013.6196 - val_loss: 50.3463 - val_mean_squared_error: 4638.2695
# Epoch 161/300
# 5/5 [==============================] - 0s 16ms/step - loss: 47.8476 - mean_squared_error: 3846.2503 - val_loss: 50.2820 - val_mean_squared_error: 4626.0752
# Epoch 162/300
# 5/5 [==============================] - 0s 12ms/step - loss: 52.0935 - mean_squared_error: 4503.8646 - val_loss: 50.2226 - val_mean_squared_error: 4614.9111
# Epoch 163/300
# 5/5 [==============================] - 0s 12ms/step - loss: 47.5555 - mean_squared_error: 3769.8104 - val_loss: 50.1654 - val_mean_squared_error: 4602.2646
# Epoch 164/300
# 5/5 [==============================] - 0s 16ms/step - loss: 45.3589 - mean_squared_error: 3624.7849 - val_loss: 50.1044 - val_mean_squared_error: 4592.0381
# Epoch 165/300
# 5/5 [==============================] - 0s 12ms/step - loss: 49.1793 - mean_squared_error: 3906.2623 - val_loss: 50.0405 - val_mean_squared_error: 4582.9790
# Epoch 166/300
# 5/5 [==============================] - 0s 12ms/step - loss: 47.2347 - mean_squared_error: 3788.1446 - val_loss: 49.9878 - val_mean_squared_error: 4574.5649
# Epoch 167/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.6623 - mean_squared_error: 3641.8295 - val_loss: 49.9200 - val_mean_squared_error: 4561.6484
# Epoch 168/300
# 5/5 [==============================] - 0s 12ms/step - loss: 48.5038 - mean_squared_error: 3946.4139 - val_loss: 49.8625 - val_mean_squared_error: 4549.4575
# Epoch 169/300
# 5/5 [==============================] - 0s 16ms/step - loss: 52.5187 - mean_squared_error: 4610.5824 - val_loss: 49.8067 - val_mean_squared_error: 4534.8730
# Epoch 170/300
# 5/5 [==============================] - 0s 14ms/step - loss: 48.3454 - mean_squared_error: 3941.5713 - val_loss: 49.7683 - val_mean_squared_error: 4519.0537
# Epoch 171/300
# 5/5 [==============================] - 0s 12ms/step - loss: 47.1438 - mean_squared_error: 3764.1446 - val_loss: 49.7005 - val_mean_squared_error: 4507.0103
# Epoch 172/300
# 5/5 [==============================] - 0s 12ms/step - loss: 47.6551 - mean_squared_error: 3733.7858 - val_loss: 49.6214 - val_mean_squared_error: 4493.1738
# Epoch 173/300
# 5/5 [==============================] - 0s 12ms/step - loss: 48.4310 - mean_squared_error: 3705.1122 - val_loss: 49.5478 - val_mean_squared_error: 4481.9858
# Epoch 174/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.6680 - mean_squared_error: 3668.6267 - val_loss: 49.4474 - val_mean_squared_error: 4470.7690
# Epoch 175/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.5581 - mean_squared_error: 3719.4052 - val_loss: 49.4044 - val_mean_squared_error: 4460.6099
# Epoch 176/300
# 5/5 [==============================] - 0s 11ms/step - loss: 46.3195 - mean_squared_error: 3407.0719 - val_loss: 49.3711 - val_mean_squared_error: 4450.4995
# Epoch 177/300
# 5/5 [==============================] - 0s 12ms/step - loss: 48.8990 - mean_squared_error: 3842.8203 - val_loss: 49.3166 - val_mean_squared_error: 4441.9150
# Epoch 178/300
# 5/5 [==============================] - 0s 17ms/step - loss: 46.5176 - mean_squared_error: 3850.5361 - val_loss: 49.2410 - val_mean_squared_error: 4434.1602
# Epoch 179/300
# 5/5 [==============================] - 0s 19ms/step - loss: 48.9426 - mean_squared_error: 4140.5765 - val_loss: 49.1154 - val_mean_squared_error: 4425.6187
# Epoch 180/300
# 5/5 [==============================] - 0s 17ms/step - loss: 45.4604 - mean_squared_error: 3425.2710 - val_loss: 49.0041 - val_mean_squared_error: 4415.2700
# Epoch 181/300
# 5/5 [==============================] - 0s 16ms/step - loss: 45.0859 - mean_squared_error: 3522.8995 - val_loss: 48.9080 - val_mean_squared_error: 4401.8286
# Epoch 182/300
# 5/5 [==============================] - 0s 11ms/step - loss: 46.2942 - mean_squared_error: 3596.5474 - val_loss: 48.8186 - val_mean_squared_error: 4384.8350
# Epoch 183/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.0802 - mean_squared_error: 3703.5856 - val_loss: 48.7438 - val_mean_squared_error: 4368.9937
# Epoch 184/300
# 5/5 [==============================] - 0s 12ms/step - loss: 48.9450 - mean_squared_error: 3879.8272 - val_loss: 48.6619 - val_mean_squared_error: 4356.1230
# Epoch 185/300
# 5/5 [==============================] - 0s 13ms/step - loss: 47.3305 - mean_squared_error: 3701.5378 - val_loss: 48.5921 - val_mean_squared_error: 4342.5884
# Epoch 186/300
# 5/5 [==============================] - 0s 14ms/step - loss: 47.6299 - mean_squared_error: 3703.7261 - val_loss: 48.5256 - val_mean_squared_error: 4330.0771
# Epoch 187/300
# 5/5 [==============================] - 0s 13ms/step - loss: 48.4699 - mean_squared_error: 3781.4215 - val_loss: 48.4584 - val_mean_squared_error: 4319.9756
# Epoch 188/300
# 5/5 [==============================] - 0s 13ms/step - loss: 47.3986 - mean_squared_error: 3635.8925 - val_loss: 48.4049 - val_mean_squared_error: 4309.9438
# Epoch 189/300
# 5/5 [==============================] - 0s 12ms/step - loss: 48.4860 - mean_squared_error: 3938.6374 - val_loss: 48.4061 - val_mean_squared_error: 4296.3027
# Epoch 190/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.2360 - mean_squared_error: 3541.6378 - val_loss: 48.3865 - val_mean_squared_error: 4287.5801
# Epoch 191/300
# 5/5 [==============================] - 0s 13ms/step - loss: 47.2483 - mean_squared_error: 3582.0566 - val_loss: 48.3773 - val_mean_squared_error: 4279.2905
# Epoch 192/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.6230 - mean_squared_error: 3430.7002 - val_loss: 48.3419 - val_mean_squared_error: 4266.1460
# Epoch 193/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.6206 - mean_squared_error: 3395.2914 - val_loss: 48.3205 - val_mean_squared_error: 4251.3779
# Epoch 194/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.3346 - mean_squared_error: 3757.9301 - val_loss: 48.2910 - val_mean_squared_error: 4235.0337
# Epoch 195/300
# 5/5 [==============================] - 0s 15ms/step - loss: 47.2080 - mean_squared_error: 3695.1431 - val_loss: 48.2383 - val_mean_squared_error: 4218.8940
# Epoch 196/300
# 5/5 [==============================] - 0s 12ms/step - loss: 45.2117 - mean_squared_error: 3432.2628 - val_loss: 48.2004 - val_mean_squared_error: 4204.2886
# Epoch 197/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.6892 - mean_squared_error: 3628.7050 - val_loss: 48.1424 - val_mean_squared_error: 4193.3120
# Epoch 198/300
# 5/5 [==============================] - 0s 17ms/step - loss: 45.7445 - mean_squared_error: 3569.6249 - val_loss: 48.1022 - val_mean_squared_error: 4185.7256
# Epoch 199/300
# 5/5 [==============================] - 0s 21ms/step - loss: 47.8496 - mean_squared_error: 3890.3866 - val_loss: 48.0288 - val_mean_squared_error: 4177.5029
# Epoch 200/300
# 5/5 [==============================] - 0s 21ms/step - loss: 46.5221 - mean_squared_error: 3509.6387 - val_loss: 47.9379 - val_mean_squared_error: 4170.1348
# Epoch 201/300
# 5/5 [==============================] - 0s 14ms/step - loss: 47.8079 - mean_squared_error: 3676.9309 - val_loss: 47.8757 - val_mean_squared_error: 4165.0024
# Epoch 202/300
# 5/5 [==============================] - 0s 13ms/step - loss: 48.6658 - mean_squared_error: 3728.4750 - val_loss: 47.8445 - val_mean_squared_error: 4159.9756
# Epoch 203/300
# 5/5 [==============================] - 0s 15ms/step - loss: 48.7062 - mean_squared_error: 3909.4137 - val_loss: 47.8547 - val_mean_squared_error: 4156.9727
# Epoch 204/300
# 5/5 [==============================] - 0s 14ms/step - loss: 45.9907 - mean_squared_error: 3495.3543 - val_loss: 47.8855 - val_mean_squared_error: 4148.3794
# Epoch 205/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.7004 - mean_squared_error: 3413.7606 - val_loss: 47.8569 - val_mean_squared_error: 4137.9395
# Epoch 206/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.8817 - mean_squared_error: 3744.6828 - val_loss: 47.8460 - val_mean_squared_error: 4129.9829
# Epoch 207/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.7964 - mean_squared_error: 3369.5671 - val_loss: 47.8613 - val_mean_squared_error: 4127.5244
# Epoch 208/300
# 5/5 [==============================] - 0s 13ms/step - loss: 46.3608 - mean_squared_error: 3794.8919 - val_loss: 47.8397 - val_mean_squared_error: 4124.0288
# Epoch 209/300
# 5/5 [==============================] - 0s 11ms/step - loss: 46.9133 - mean_squared_error: 3618.0017 - val_loss: 47.7921 - val_mean_squared_error: 4117.7446
# Epoch 210/300
# 5/5 [==============================] - 0s 12ms/step - loss: 47.3105 - mean_squared_error: 3658.1568 - val_loss: 47.7407 - val_mean_squared_error: 4112.1304
# Epoch 211/300
# 5/5 [==============================] - 0s 18ms/step - loss: 46.0704 - mean_squared_error: 3339.4715 - val_loss: 47.6757 - val_mean_squared_error: 4103.6226
# Epoch 212/300
# 5/5 [==============================] - 0s 13ms/step - loss: 43.0076 - mean_squared_error: 3138.9535 - val_loss: 47.6057 - val_mean_squared_error: 4093.0916
# Epoch 213/300
# 5/5 [==============================] - 0s 13ms/step - loss: 43.9293 - mean_squared_error: 3233.5068 - val_loss: 47.5193 - val_mean_squared_error: 4082.8267
# Epoch 214/300
# 5/5 [==============================] - 0s 23ms/step - loss: 44.5389 - mean_squared_error: 3550.7897 - val_loss: 47.4413 - val_mean_squared_error: 4076.0674
# Epoch 215/300
# 5/5 [==============================] - 0s 16ms/step - loss: 45.8243 - mean_squared_error: 3470.4828 - val_loss: 47.3487 - val_mean_squared_error: 4067.1550
# Epoch 216/300
# 5/5 [==============================] - 0s 13ms/step - loss: 45.5127 - mean_squared_error: 3494.0113 - val_loss: 47.2779 - val_mean_squared_error: 4058.1880
# Epoch 217/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.4669 - mean_squared_error: 3535.5813 - val_loss: 47.2190 - val_mean_squared_error: 4048.1880
# Epoch 218/300
# 5/5 [==============================] - 0s 12ms/step - loss: 47.9289 - mean_squared_error: 3692.1610 - val_loss: 47.1328 - val_mean_squared_error: 4033.8047
# Epoch 219/300
# 5/5 [==============================] - 0s 16ms/step - loss: 45.5700 - mean_squared_error: 3408.5932 - val_loss: 47.0971 - val_mean_squared_error: 4026.5176
# Epoch 220/300
# 5/5 [==============================] - 0s 15ms/step - loss: 43.0212 - mean_squared_error: 3066.3570 - val_loss: 47.0485 - val_mean_squared_error: 4019.7883
# Epoch 221/300
# 5/5 [==============================] - 0s 13ms/step - loss: 46.8503 - mean_squared_error: 3630.3497 - val_loss: 46.9503 - val_mean_squared_error: 4007.9146
# Epoch 222/300
# 5/5 [==============================] - 0s 14ms/step - loss: 46.5312 - mean_squared_error: 3496.8492 - val_loss: 46.8366 - val_mean_squared_error: 4001.2446
# Epoch 223/300
# 5/5 [==============================] - 0s 13ms/step - loss: 45.0113 - mean_squared_error: 3283.8355 - val_loss: 46.7732 - val_mean_squared_error: 3992.3125
# Epoch 224/300
# 5/5 [==============================] - 0s 12ms/step - loss: 47.1205 - mean_squared_error: 3534.2023 - val_loss: 46.7281 - val_mean_squared_error: 3984.0955
# Epoch 225/300
# 5/5 [==============================] - 0s 12ms/step - loss: 45.9621 - mean_squared_error: 3429.9441 - val_loss: 46.6600 - val_mean_squared_error: 3975.3201
# Epoch 226/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.6493 - mean_squared_error: 3234.9486 - val_loss: 46.5994 - val_mean_squared_error: 3966.8306
# Epoch 227/300
# 5/5 [==============================] - 0s 15ms/step - loss: 44.3645 - mean_squared_error: 3037.1876 - val_loss: 46.6017 - val_mean_squared_error: 3961.6245
# Epoch 228/300
# 5/5 [==============================] - 0s 16ms/step - loss: 44.4222 - mean_squared_error: 3348.1000 - val_loss: 46.5953 - val_mean_squared_error: 3959.0190
# Epoch 229/300
# 5/5 [==============================] - 0s 19ms/step - loss: 44.0101 - mean_squared_error: 3197.0411 - val_loss: 46.5862 - val_mean_squared_error: 3957.8428
# Epoch 230/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.6673 - mean_squared_error: 3267.2323 - val_loss: 46.5550 - val_mean_squared_error: 3956.1479
# Epoch 231/300
# 5/5 [==============================] - 0s 13ms/step - loss: 50.4443 - mean_squared_error: 4038.0701 - val_loss: 46.5104 - val_mean_squared_error: 3952.8279
# Epoch 232/300
# 5/5 [==============================] - 0s 13ms/step - loss: 44.3685 - mean_squared_error: 3406.1599 - val_loss: 46.4764 - val_mean_squared_error: 3950.8428
# Epoch 233/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.1197 - mean_squared_error: 3604.6657 - val_loss: 46.4453 - val_mean_squared_error: 3947.2874
# Epoch 234/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.5426 - mean_squared_error: 3293.7966 - val_loss: 46.4265 - val_mean_squared_error: 3944.7632
# Epoch 235/300
# 5/5 [==============================] - 0s 12ms/step - loss: 45.0860 - mean_squared_error: 3396.1395 - val_loss: 46.3808 - val_mean_squared_error: 3940.1431
# Epoch 236/300
# 5/5 [==============================] - 0s 13ms/step - loss: 44.6729 - mean_squared_error: 3401.2344 - val_loss: 46.3195 - val_mean_squared_error: 3929.2297
# Epoch 237/300
# 5/5 [==============================] - 0s 13ms/step - loss: 48.2388 - mean_squared_error: 3967.0374 - val_loss: 46.2707 - val_mean_squared_error: 3919.9036
# Epoch 238/300
# 5/5 [==============================] - 0s 13ms/step - loss: 45.0827 - mean_squared_error: 3282.1154 - val_loss: 46.2388 - val_mean_squared_error: 3913.3447
# Epoch 239/300
# 5/5 [==============================] - 0s 12ms/step - loss: 45.0392 - mean_squared_error: 3383.1136 - val_loss: 46.2005 - val_mean_squared_error: 3908.4568
# Epoch 240/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.9268 - mean_squared_error: 3637.7718 - val_loss: 46.1808 - val_mean_squared_error: 3904.1135
# Epoch 241/300
# 5/5 [==============================] - 0s 12ms/step - loss: 43.8971 - mean_squared_error: 3328.8285 - val_loss: 46.2259 - val_mean_squared_error: 3897.5242
# Epoch 242/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.3338 - mean_squared_error: 3508.0860 - val_loss: 46.2282 - val_mean_squared_error: 3891.2275
# Epoch 243/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.6229 - mean_squared_error: 3449.0217 - val_loss: 46.2377 - val_mean_squared_error: 3886.0168
# Epoch 244/300
# 5/5 [==============================] - 0s 16ms/step - loss: 44.7466 - mean_squared_error: 3327.2587 - val_loss: 46.2267 - val_mean_squared_error: 3882.7878
# Epoch 245/300
# 5/5 [==============================] - 0s 12ms/step - loss: 45.2057 - mean_squared_error: 3365.7350 - val_loss: 46.1988 - val_mean_squared_error: 3877.0071
# Epoch 246/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.7742 - mean_squared_error: 3470.4879 - val_loss: 46.1279 - val_mean_squared_error: 3868.1328
# Epoch 247/300
# 5/5 [==============================] - 0s 13ms/step - loss: 47.9821 - mean_squared_error: 3755.2140 - val_loss: 46.0712 - val_mean_squared_error: 3861.7720
# Epoch 248/300
# 5/5 [==============================] - 0s 15ms/step - loss: 45.2255 - mean_squared_error: 3332.7121 - val_loss: 46.0694 - val_mean_squared_error: 3855.8557
# Epoch 249/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.1113 - mean_squared_error: 3074.5181 - val_loss: 46.0282 - val_mean_squared_error: 3849.4568
# Epoch 250/300
# 5/5 [==============================] - 0s 13ms/step - loss: 44.9018 - mean_squared_error: 3384.5609 - val_loss: 45.9549 - val_mean_squared_error: 3843.3289
# Epoch 251/300
# 5/5 [==============================] - 0s 12ms/step - loss: 49.1002 - mean_squared_error: 3994.6964 - val_loss: 45.8866 - val_mean_squared_error: 3837.7249
# Epoch 252/300
# 5/5 [==============================] - 0s 12ms/step - loss: 45.4038 - mean_squared_error: 3499.2694 - val_loss: 45.8342 - val_mean_squared_error: 3830.0713
# Epoch 253/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.4330 - mean_squared_error: 3570.4008 - val_loss: 45.7823 - val_mean_squared_error: 3826.0752
# Epoch 254/300
# 5/5 [==============================] - 0s 14ms/step - loss: 41.5230 - mean_squared_error: 2894.1219 - val_loss: 45.7423 - val_mean_squared_error: 3818.8931
# Epoch 255/300
# 5/5 [==============================] - 0s 16ms/step - loss: 46.3124 - mean_squared_error: 3471.5525 - val_loss: 45.7380 - val_mean_squared_error: 3812.0269
# Epoch 256/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.9778 - mean_squared_error: 3333.9513 - val_loss: 45.7143 - val_mean_squared_error: 3804.6990
# Epoch 257/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.0470 - mean_squared_error: 3180.3285 - val_loss: 45.7383 - val_mean_squared_error: 3800.1487
# Epoch 258/300
# 5/5 [==============================] - 0s 12ms/step - loss: 41.4130 - mean_squared_error: 2955.1752 - val_loss: 45.7631 - val_mean_squared_error: 3795.9524
# Epoch 259/300
# 5/5 [==============================] - 0s 12ms/step - loss: 43.5765 - mean_squared_error: 3204.6174 - val_loss: 45.8100 - val_mean_squared_error: 3791.3689
# Epoch 260/300
# 5/5 [==============================] - 0s 12ms/step - loss: 45.5217 - mean_squared_error: 3368.2968 - val_loss: 45.8418 - val_mean_squared_error: 3788.8652
# Epoch 261/300
# 5/5 [==============================] - 0s 15ms/step - loss: 44.0752 - mean_squared_error: 3275.7087 - val_loss: 45.8422 - val_mean_squared_error: 3784.9934
# Epoch 262/300
# 5/5 [==============================] - 0s 12ms/step - loss: 47.2064 - mean_squared_error: 3604.5508 - val_loss: 45.7936 - val_mean_squared_error: 3776.0098
# Epoch 263/300
# 5/5 [==============================] - 0s 12ms/step - loss: 45.4706 - mean_squared_error: 3465.8486 - val_loss: 45.7514 - val_mean_squared_error: 3763.8157
# Epoch 264/300
# 5/5 [==============================] - 0s 13ms/step - loss: 42.5412 - mean_squared_error: 3124.1532 - val_loss: 45.6944 - val_mean_squared_error: 3753.1350
# Epoch 265/300
# 5/5 [==============================] - 0s 16ms/step - loss: 44.2653 - mean_squared_error: 3347.3224 - val_loss: 45.6338 - val_mean_squared_error: 3746.0959
# Epoch 266/300
# 5/5 [==============================] - 0s 18ms/step - loss: 45.5292 - mean_squared_error: 3286.1194 - val_loss: 45.5785 - val_mean_squared_error: 3741.6069
# Epoch 267/300
# 5/5 [==============================] - 0s 13ms/step - loss: 47.0981 - mean_squared_error: 3564.7797 - val_loss: 45.5390 - val_mean_squared_error: 3739.5837
# Epoch 268/300
# 5/5 [==============================] - 0s 13ms/step - loss: 45.5219 - mean_squared_error: 3450.0540 - val_loss: 45.5151 - val_mean_squared_error: 3737.8701
# Epoch 269/300
# 5/5 [==============================] - 0s 14ms/step - loss: 45.8060 - mean_squared_error: 3380.2278 - val_loss: 45.4787 - val_mean_squared_error: 3737.2981
# Epoch 270/300
# 5/5 [==============================] - 0s 13ms/step - loss: 45.1291 - mean_squared_error: 3193.2196 - val_loss: 45.4944 - val_mean_squared_error: 3738.2927
# Epoch 271/300
# 5/5 [==============================] - 0s 16ms/step - loss: 49.0837 - mean_squared_error: 3886.8223 - val_loss: 45.4802 - val_mean_squared_error: 3736.9358
# Epoch 272/300
# 5/5 [==============================] - 0s 14ms/step - loss: 45.4932 - mean_squared_error: 3494.2594 - val_loss: 45.4889 - val_mean_squared_error: 3734.2878
# Epoch 273/300
# 5/5 [==============================] - 0s 16ms/step - loss: 45.5171 - mean_squared_error: 3276.4152 - val_loss: 45.5121 - val_mean_squared_error: 3734.4529
# Epoch 274/300
# 5/5 [==============================] - 0s 12ms/step - loss: 46.4889 - mean_squared_error: 3518.0179 - val_loss: 45.5283 - val_mean_squared_error: 3732.0942
# Epoch 275/300
# 5/5 [==============================] - 0s 12ms/step - loss: 42.7354 - mean_squared_error: 3029.9428 - val_loss: 45.5515 - val_mean_squared_error: 3728.2966
# Epoch 276/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.1552 - mean_squared_error: 3253.3172 - val_loss: 45.5332 - val_mean_squared_error: 3725.9973
# Epoch 277/300
# 5/5 [==============================] - 0s 11ms/step - loss: 45.9854 - mean_squared_error: 3422.2588 - val_loss: 45.5272 - val_mean_squared_error: 3723.5488
# Epoch 278/300
# 5/5 [==============================] - 0s 16ms/step - loss: 42.2080 - mean_squared_error: 3081.7205 - val_loss: 45.4789 - val_mean_squared_error: 3721.9189
# Epoch 279/300
# 5/5 [==============================] - 0s 12ms/step - loss: 43.6231 - mean_squared_error: 3254.3412 - val_loss: 45.4063 - val_mean_squared_error: 3715.2500
# Epoch 280/300
# 5/5 [==============================] - 0s 19ms/step - loss: 42.9767 - mean_squared_error: 3051.0257 - val_loss: 45.3375 - val_mean_squared_error: 3707.9858
# Epoch 281/300
# 5/5 [==============================] - 0s 29ms/step - loss: 45.6933 - mean_squared_error: 3587.3612 - val_loss: 45.2834 - val_mean_squared_error: 3699.9441
# Epoch 282/300
# 5/5 [==============================] - 0s 11ms/step - loss: 42.2458 - mean_squared_error: 2845.1949 - val_loss: 45.2636 - val_mean_squared_error: 3691.1965
# Epoch 283/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.0694 - mean_squared_error: 3215.8938 - val_loss: 45.2771 - val_mean_squared_error: 3684.2473
# Epoch 284/300
# 5/5 [==============================] - 0s 11ms/step - loss: 44.2870 - mean_squared_error: 3316.1283 - val_loss: 45.3027 - val_mean_squared_error: 3678.1841
# Epoch 285/300
# 5/5 [==============================] - 0s 12ms/step - loss: 45.7622 - mean_squared_error: 3379.6970 - val_loss: 45.3104 - val_mean_squared_error: 3672.0342
# Epoch 286/300
# 5/5 [==============================] - 0s 11ms/step - loss: 40.5171 - mean_squared_error: 2950.5925 - val_loss: 45.3291 - val_mean_squared_error: 3671.1689
# Epoch 287/300
# 5/5 [==============================] - 0s 13ms/step - loss: 43.0622 - mean_squared_error: 3199.4737 - val_loss: 45.3034 - val_mean_squared_error: 3672.2258
# Epoch 288/300
# 5/5 [==============================] - 0s 16ms/step - loss: 47.9293 - mean_squared_error: 3652.4314 - val_loss: 45.2632 - val_mean_squared_error: 3668.6172
# Epoch 289/300
# 5/5 [==============================] - 0s 16ms/step - loss: 47.0783 - mean_squared_error: 3668.6880 - val_loss: 45.2718 - val_mean_squared_error: 3663.2673
# Epoch 290/300
# 5/5 [==============================] - 0s 11ms/step - loss: 44.5572 - mean_squared_error: 3229.2270 - val_loss: 45.2691 - val_mean_squared_error: 3658.1885
# Epoch 291/300
# 5/5 [==============================] - 0s 18ms/step - loss: 43.7552 - mean_squared_error: 3226.5255 - val_loss: 45.2298 - val_mean_squared_error: 3652.8293
# Epoch 292/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.8121 - mean_squared_error: 3193.4479 - val_loss: 45.2061 - val_mean_squared_error: 3647.2285
# Epoch 293/300
# 5/5 [==============================] - 0s 16ms/step - loss: 45.4027 - mean_squared_error: 3420.3326 - val_loss: 45.1836 - val_mean_squared_error: 3641.7715
# Epoch 294/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.3351 - mean_squared_error: 3123.0897 - val_loss: 45.1622 - val_mean_squared_error: 3632.0352
# Epoch 295/300
# 5/5 [==============================] - 0s 12ms/step - loss: 42.3101 - mean_squared_error: 3055.6458 - val_loss: 45.1633 - val_mean_squared_error: 3623.4592
# Epoch 296/300
# 5/5 [==============================] - 0s 13ms/step - loss: 45.1210 - mean_squared_error: 3319.6741 - val_loss: 45.1544 - val_mean_squared_error: 3619.4978
# Epoch 297/300
# 5/5 [==============================] - 0s 11ms/step - loss: 46.4130 - mean_squared_error: 3470.5801 - val_loss: 45.1481 - val_mean_squared_error: 3618.6931
# Epoch 298/300
# 5/5 [==============================] - 0s 12ms/step - loss: 43.5007 - mean_squared_error: 3137.6209 - val_loss: 45.1375 - val_mean_squared_error: 3617.1685
# Epoch 299/300
# 5/5 [==============================] - 0s 12ms/step - loss: 42.5559 - mean_squared_error: 3013.4334 - val_loss: 45.1246 - val_mean_squared_error: 3615.5972
# Epoch 300/300
# 5/5 [==============================] - 0s 12ms/step - loss: 44.1823 - mean_squared_error: 3455.5658 - val_loss: 45.1013 - val_mean_squared_error: 3609.3606

# %%
for key in ['loss', 'val_loss']:
    plt.plot(np.arange(1, n_epochs+1), history.history[key], label=key)
plt.legend()
plt.show()

print(np.argmin(history.history['val_loss']))
print(np.where(history.history['val_loss'] == np.min(history.history['val_loss'])))
# Out:
# 299
# (array([299]),)

# %%
model_name = "Neural network"
print_errors(model, model_name, X_test, y_test)
# Out:
# RMSE (Neural network): 63.249175795575304
# R-squared score (Neural network) : 0.47479088252157353

# %% [markdown]
# ## SHAP

# %%
### Make seperate plot for each one, and also one with all the shaps combined (can be used later in the report)
idx = 4
model_name = "Neural network"

X_test_df = pd.DataFrame(X_test, columns=feature_names)

def nn_predict(X):
    y_pred = model.predict(X)
    y_pred = np.reshape(y_pred, X.shape[0])
    return classify(np.array(y_pred))


explainers[model_name] = shap.KernelExplainer(model = model.predict,data=X_train, link="identity")

shap_test = explainers[model_name].shap_values(X_test_df.iloc[idx])

print(shap_test[0])

# PLOT SHAPLEY VALUES IN NORMAL WAY

shap.initjs()
shap.force_plot(explainers[model_name].expected_value, 
    shap_test[0],
     X_test_df.iloc[idx])
# shap.force_plot(explainer.expected_value[1], shap_test[1], X_test_df.iloc[idx]) # for decision trees
# Out:
# Using 282 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
# [ 16.70617469  -8.49367502 -16.83639849  -0.07067819  -1.58852527
#    5.98701928  -9.37858908  -3.41367965  14.16636175   1.23962373]
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='i5RLM83I1ZS2F4LIHDCR1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 137.478630891083, "outValue": 135.7962646484375, "link": "identity", "featureNames": ["age", "sex", "bmi", "bp", "s1", "s2", "s3", "s4", "s5", "s6"], "features": {"0": {"effect": 16.706174693292215, "value": 1.3350883235096633}, "1": {"effect": -8.493675020948002, "value": 1.0654884797514645}, "2": {"effect": -16.836398492935132, "value": -0.5383473358194506}, "3": {"effect": -0.07067819108677764, "value": 0.24269329657561015}, "4": {"effect": -1.5885252679372726, "value": 1.3555466169207542}, "5": {"effect": 5.987019280819379, "value": 1.0191648422021304}, "6": {"effect": -9.3785890836349, "value": 0.6355895188230916}, "7": {"effect": -3.41367964548639, "value": -0.054499187536269665}, "8": {"effect": 14.166361752364763, "value": 0.8071718197783121}, "9": {"effect": 1.2396237329066313, "value": 0.41275676235612696}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i5RLM83I1ZS2F4LIHDCR1')
#   );
# </script>

# %%
shap_values_all = dict()
X_test_df = pd.DataFrame(X_test, columns=feature_names)

explainer = explainers[model_name]
shap_values[model_name] = explainer.shap_values(X_test_df.iloc[:5])
shap_values_all = shap_values[model_name]
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
shapley_feat_imps = pd.DataFrame(index=feature_names)

shap_value = shap_values_all
feat_imps = np.mean(np.abs(shap_value), axis=0)
feat_imps /= np.sum(feat_imps)


shapley_feat_imps.insert(0, model_name, feat_imps[0])
shapley_feat_imps.plot.bar()
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=90a57419-7b7b-4aa4-8a97-858f9f98a849' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
